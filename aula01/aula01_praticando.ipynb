# %%
print("Marcos Vinício")
print("Ramos Camara")
# Out:
# Marcos Vinício
# Ramos Camara

# %%
nome_filme = "O Gardião"

# %%
print(nome_filme)
# Out:
# O Gardião

# %%
nome_filme
# Out:
# 'O Gardião'

# %%
import pandas as pd

# %%
filmes = pd.read_csv("https://raw.githubusercontent.com/marcosvrc/quarentenadadosalura/master/datasets/movies.csv")
filmes.columns = ["filmeId", "titulos", "generos"]
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
#Lendo a documentação de um método/atributo --> Coloca uma ? antes
? filmes.head()

# %%
avaliacoes = pd.read_csv("https://raw.githubusercontent.com/marcosvrc/quarentenadadosalura/master/datasets/ratings.csv")
avaliacoes.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
avaliacoes.shape
# Out:
# (100836, 4)

# %%
len(avaliacoes)
# Out:
# 100836

# %%
avaliacoes.columns = ["usuarioId", "filmeId", "nota", "momento"]
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
avaliacoes_filme_1 = avaliacoes.query("filmeId == 1")
avaliacoes_filme_1.head()
# Out:
#       usuarioId  filmeId  nota     momento
# 0             1        1   4.0   964982703
# 516           5        1   4.0   847434962
# 874           7        1   4.5  1106635946
# 1434         15        1   2.5  1510577970
# 1667         17        1   4.5  1305696483

# %%
avaliacoes_filme_1.describe()
# Out:
#         usuarioId  filmeId        nota       momento
# count  215.000000    215.0  215.000000  2.150000e+02
# mean   306.530233      1.0    3.920930  1.129835e+09
# std    180.419754      0.0    0.834859  2.393163e+08
# min      1.000000      1.0    0.500000  8.293223e+08
# 25%    155.500000      1.0    3.500000  8.779224e+08
# 50%    290.000000      1.0    4.000000  1.106855e+09
# 75%    468.500000      1.0    4.500000  1.348523e+09
# max    610.000000      1.0    5.000000  1.535710e+09

# %%
avaliacoes_filme_1.mean()
# Out:
# usuarioId    3.065302e+02
# filmeId      1.000000e+00
# nota         3.920930e+00
# momento      1.129835e+09
# dtype: float64

# %%
avaliacoes["nota"]
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
avaliacoes["nota"].mean()
# Out:
# 3.501556983616962

# %%
avaliacoes_filme_1["nota"].mean()
# Out:
# 3.9209302325581397

# %%
notas_media_filme = avaliacoes.groupby("filmeId")["nota"].mean()
notas_media_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
filmes
# Out:
#       filmeId  ...                                      generos
# 0           1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1           2  ...                   Adventure|Children|Fantasy
# 2           3  ...                               Comedy|Romance
# 3           4  ...                         Comedy|Drama|Romance
# 4           5  ...                                       Comedy
# ...       ...  ...                                          ...
# 9737   193581  ...              Action|Animation|Comedy|Fantasy
# 9738   193583  ...                     Animation|Comedy|Fantasy
# 9739   193585  ...                                        Drama
# 9740   193587  ...                             Action|Animation
# 9741   193609  ...                                       Comedy
#
# [9742 rows x 3 columns]

# %%
notas_media_filme
# Out:
# filmeId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
filme_media = filmes.join(notas_media_filme, on="filmeId")
filme_media.head()
# Out:
#    filmeId  ...      nota
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %%
filme_media.sort_values("nota", ascending=False).head(15)
# Out:
#       filmeId  ... nota
# 7656    88448  ...  5.0
# 8107   100556  ...  5.0
# 9083   143031  ...  5.0
# 9094   143511  ...  5.0
# 9096   143559  ...  5.0
# 4251     6201  ...  5.0
# 8154   102217  ...  5.0
# 8148   102084  ...  5.0
# 4246     6192  ...  5.0
# 9122   145994  ...  5.0
# 8115   100906  ...  5.0
# 9129   146662  ...  5.0
# 8074    99636  ...  5.0
# 5785    31522  ...  5.0
# 9131   146684  ...  5.0
#
# [15 rows x 4 columns]

# %%
avaliacoes.query("filmeId == 1")["nota"].plot()

# %%
avaliacoes.query("filmeId == 1")["nota"].plot(kind='hist')

# %%
avaliacoes.query("filmeId == 1")["nota"].plot(kind='hist', title = 'Avaliacoes do Filme Toy Story')

# %%
import matplotlib.pyplot as plt

avaliacoes.query("filmeId == 1")["nota"].plot(kind='hist')
plt.title("Avaliacao do filme Toy Story")
plt.show()

# %%
avaliacoes.query("filmeId == 2")["nota"].plot(kind='hist', title="Avaliacao do filme Jumanji")

# %%
avaliacoes.query("filmeId == 102084")["nota"].plot(kind='hist',
                                                   title="Avaliações do filme Justice League: Doom")
