# %%
import pandas as pd

filmes = pd.read_csv("https://raw.githubusercontent.com/marcosvrc/quarentenadadosalura/master/datasets/movies.csv")
avaliacoes = pd.read_csv("https://raw.githubusercontent.com/marcosvrc/quarentenadadosalura/master/datasets/ratings.csv")

avaliacoes.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
avaliacoes.columns = ["usuarioId","filmeId","nota", "momento"]
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
filmes.columns = ["filmeId","titulos","generos"]
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
notas_media_filme = avaliacoes.groupby("filmeId")["nota"].mean()
notas_media_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
filme_media = filmes.join(notas_media_filme, on="filmeId")
filme_media.head()
# Out:
#    filmeId  ...      nota
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %% [markdown]
# # Desafio 1

# %%
selecao = filme_media['nota'].isnull()
filme_media[selecao]
# Out:
#       filmeId  ... nota
# 816      1076  ...  NaN
# 2211     2939  ...  NaN
# 2499     3338  ...  NaN
# 2587     3456  ...  NaN
# 3118     4194  ...  NaN
# 4037     5721  ...  NaN
# 4506     6668  ...  NaN
# 4598     6849  ...  NaN
# 4704     7020  ...  NaN
# 5020     7792  ...  NaN
# 5293     8765  ...  NaN
# 5421    25855  ...  NaN
# 5452    26085  ...  NaN
# 5749    30892  ...  NaN
# 5824    32160  ...  NaN
# 5837    32371  ...  NaN
# 5957    34482  ...  NaN
# 7565    85565  ...  NaN
#
# [18 rows x 4 columns]

# %% [markdown]
# Desafio 2

# %%
filme_media = filme_media.rename(columns={'nota': 'nota_media'})
filme_media.head()
# Out:
#    filmeId  ... nota_media
# 0        1  ...   3.920930
# 1        2  ...   3.431818
# 2        3  ...   3.259615
# 3        4  ...   2.357143
# 4        5  ...   3.071429
#
# [5 rows x 4 columns]

# %% [markdown]
# # Desafio 3

# %%
total_votos_filme = avaliacoes.groupby('filmeId')['nota'].count()
total_votos_filme.head()
# Out:
# filmeId
# 1    215
# 2    110
# 3     52
# 4      7
# 5     49
# Name: nota, dtype: int64

# %%
filmes_media_e_votos = filme_media.join(total_votos_filme, on="filmeId")
filmes_media_e_votos = filmes_media_e_votos.rename(columns={'nota' : 'total_votos'})
filmes_media_e_votos.head()
# Out:
#    filmeId                             titulos  ... nota_media  total_votos
# 0        1                    Toy Story (1995)  ...   3.920930        215.0
# 1        2                      Jumanji (1995)  ...   3.431818        110.0
# 2        3             Grumpier Old Men (1995)  ...   3.259615         52.0
# 3        4            Waiting to Exhale (1995)  ...   2.357143          7.0
# 4        5  Father of the Bride Part II (1995)  ...   3.071429         49.0
#
# [5 rows x 5 columns]

# %% [markdown]
# # Desafio 4

# %%
filmes_media_e_votos['nota_media'] = filmes_media_e_votos['nota_media'].round(2)
filmes_media_e_votos
# Out:
#       filmeId  ... total_votos
# 0           1  ...       215.0
# 1           2  ...       110.0
# 2           3  ...        52.0
# 3           4  ...         7.0
# 4           5  ...        49.0
# ...       ...  ...         ...
# 9737   193581  ...         1.0
# 9738   193583  ...         1.0
# 9739   193585  ...         1.0
# 9740   193587  ...         1.0
# 9741   193609  ...         1.0
#
# [9742 rows x 5 columns]

# %% [markdown]
# # Desafio 5

# %%
generos_df = filmes_media_e_votos.generos.str.get_dummies('|')
generos = generos_df.columns.to_list()
generos
# Out:
# ['(no genres listed)',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'IMAX',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western']

# %% [markdown]
# # Desafio 6

# %%
total_filmes_por_genero = filmes_media_e_votos.generos.str.get_dummies().sum()
total_filmes_por_genero.sort_values(ascending=False)
# Out:
# Drama                 4361
# Comedy                3756
# Thriller              1894
# Action                1828
# Romance               1596
# Adventure             1263
# Crime                 1199
# Sci-Fi                 980
# Horror                 978
# Fantasy                779
# Children               664
# Animation              611
# Mystery                573
# Documentary            440
# War                    382
# Musical                334
# Western                167
# IMAX                   158
# Film-Noir               87
# (no genres listed)      34
# dtype: int64

# %% [markdown]
# # Desafio 7

# %%
total_filmes_por_genero.sort_values(ascending=False).plot(kind='bar', figsize=(16,6))
