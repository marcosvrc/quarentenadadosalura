# %%
import pandas as pd
filmes = pd.read_csv("https://raw.githubusercontent.com/marcosvrc/quarentenadadosalura/master/datasets/movies.csv")
avaliacoes = pd.read_csv("https://raw.githubusercontent.com/marcosvrc/quarentenadadosalura/master/datasets/ratings.csv")

# %%
filmes.columns = ["filmeId", "titulos", "generos"]
avaliacoes.columns = ["usuarioId", "filmeId", "nota", "momento"]

# %%
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
avaliacoes.min()
# Out:
# usuarioId            1.0
# filmeId              1.0
# nota                 0.5
# momento      828124615.0
# dtype: float64

# %%
notas_media_filme = avaliacoes.groupby("filmeId")["nota"].mean()
notas_media_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
filme_media = filmes.join(notas_media_filme, on="filmeId")
filme_media.head()
# Out:
#    filmeId  ...      nota
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %%
filme_media.sort_values("nota", ascending=False).head(15)
# Out:
#       filmeId  ... nota
# 7656    88448  ...  5.0
# 8107   100556  ...  5.0
# 9083   143031  ...  5.0
# 9094   143511  ...  5.0
# 9096   143559  ...  5.0
# 4251     6201  ...  5.0
# 8154   102217  ...  5.0
# 8148   102084  ...  5.0
# 4246     6192  ...  5.0
# 9122   145994  ...  5.0
# 8115   100906  ...  5.0
# 9129   146662  ...  5.0
# 8074    99636  ...  5.0
# 5785    31522  ...  5.0
# 9131   146684  ...  5.0
#
# [15 rows x 4 columns]

# %% [markdown]
# ## Desafio 1 do Paulo Silveira
# O Paulo fez uma análise rápida e disse que tem 18 filmes sem avaliações, será que ele acertou?
#
# Determine quantos filmes não tem avaliações e quais são esses filmes.

# %%
## Verificando a existência de valores null. O campo notas tem 18 itens sem avaliação
filme_media.isnull().sum()
# Out:
# filmeId     0
# titulos     0
# generos     0
# nota       18
# dtype: int64

# %%
#Para saber todas as colunas
#Faz o filtro pelo índice verificando que está null
filme_media[filme_media.nota.isnull()]


#Para saber apenas uma coluna
#filme_media[filme_media.nota.isnull()]["titulos"]
# Out:
#       filmeId  ... nota
# 816      1076  ...  NaN
# 2211     2939  ...  NaN
# 2499     3338  ...  NaN
# 2587     3456  ...  NaN
# 3118     4194  ...  NaN
# 4037     5721  ...  NaN
# 4506     6668  ...  NaN
# 4598     6849  ...  NaN
# 4704     7020  ...  NaN
# 5020     7792  ...  NaN
# 5293     8765  ...  NaN
# 5421    25855  ...  NaN
# 5452    26085  ...  NaN
# 5749    30892  ...  NaN
# 5824    32160  ...  NaN
# 5837    32371  ...  NaN
# 5957    34482  ...  NaN
# 7565    85565  ...  NaN
#
# [18 rows x 4 columns]

# %% [markdown]
# # Desafio 2 do Guilherme Silveira
# Mudar o nome da coluna nota do dataframe filmes_com_media para nota_média após o join.

# %%
filme_media.rename(columns={"nota": "nota_média"}).head()
# Out:
#    filmeId  ... nota_média
# 0        1  ...   3.920930
# 1        2  ...   3.431818
# 2        3  ...   3.259615
# 3        4  ...   2.357143
# 4        5  ...   3.071429
#
# [5 rows x 4 columns]

# %% [markdown]
# # Desafio 3 do Guilherme Silveira
# Colocar o número de avaliações por filme, isto é, não só a média mas o TOTAL de votos por filme.

# %%
tests = filme_media.groupby("titulos")["titulos"].count()
tests.tail()
# Out:
# titulos
# eXistenZ (1999)                              1
# xXx (2002)                                   1
# xXx: State of the Union (2005)               1
# ¡Three Amigos! (1986)                        1
# À nous la liberté (Freedom for Us) (1931)    1
# Name: titulos, dtype: int64

# %% [markdown]
# # Desafio 4 do Thiago Gonçalves
# Arredondar as médias (coluna de nota média) para duas casas decimais.

# %%
notas_media_filme.round(2).head()
# Out:
# filmeId
# 1    3.92
# 2    3.43
# 3    3.26
# 4    2.36
# 5    3.07
# Name: nota, dtype: float64

# %% [markdown]
# # Desafio 5 do Allan Spadini
# Descobrir os generos dos filmes (quais são eles, únicos). (esse aqui o bicho pega)

# %%
filme_media['generos'].str.split('|',expand=True).stack().unique()
# Out:
# array(['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy',
#        'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror',
#        'Mystery', 'Sci-Fi', 'War', 'Musical', 'Documentary', 'IMAX',
#        'Western', 'Film-Noir', '(no genres listed)'], dtype=object)

# %% [markdown]
# # Desafio 6 da Thais André
# Contar o número de aparições de cada genero.

# %% [markdown]
# # Desafio 7 do Guilherme Silveira
# Plotar o gráfico de aparições de cada genero. Pode ser um gráfico de tipo igual a barra.
